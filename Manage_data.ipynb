# %%
import pandas as pd


dataframe = pd.read_csv("Cancellations2022.csv")
dataframe.head(5)

#print(dataframe["Documento"].count())

stra_sample=dataframe.groupby("DV").apply(lambda x: x.sample(n=1)).reset_index(drop=True)

print(stra_sample)

#stra_sample.to_csv("C:/Users/joparra/Downloads/sample.csv")
# Out:
#    Documento  Serie     Emisión Vencimiento       RUT DV  \
# 0       7596     61  12/31/2022         NaN  99581960  0
# 1       7504     61   4/30/2022         NaN  98000000  1
# 2       7501     61   4/30/2022         NaN  96806980  2
# 3       7486     61   2/28/2022  30/03/2022  79791730  3
# 4       7557     61   8/31/2022  30/10/2022  76672000  5
# 5       7494     61   3/31/2022  08/04/2022  53310572  6
# 6       7481     61   2/28/2022  19/03/2022  92580000  7
# 7       7510     61   4/30/2022         NaN  99500840  8
# 8       7593     61  12/31/2022         NaN  77378155  9
# 9       7477     61   1/31/2022  21/01/2022  77261280  K
#
#                                Nombre Cliente                        Producto  \
# 0                   ADMINISTRADORA PLAZA S.A.       SERV. MARKETING DE DATOS
# 1                                 AFP CAPITAL                  DATA BUSQUEDA
# 2           ENTEL PCS TELECOMUNICACIONES S.A.                            IDV
# ...

# %%
withoutNA = dataframe.fillna(0)
withoutNA
# Out:
#     Documento  Serie    Emisión          Vencimiento       RUT DV  \
# 0        7476   61.0 2022-01-31  2022-09-02 00:00:00  76863650  8
# 1        7477   61.0 2022-01-31  2022-01-21 00:00:00  77261280  K
# 2        7478   61.0 2022-01-31  2022-12-02 00:00:00  96806980  2
# 3        7479   61.0 2022-01-31  2022-12-02 00:00:00  96806980  2
# 4        7479   61.0 2022-01-31  2022-12-02 00:00:00  96806980  2
# ..        ...    ...        ...                  ...       ... ..
# 128      7596   61.0 2022-12-31                    0  99581960  0
# 129      7597   61.0 2022-12-31                    0  77140321  2
# 130      7598   61.0 2022-12-31                    0  96656410  5
# 131      7599   61.0 2022-12-31                    0  96655860  1
# 132      7600   61.0 2022-12-31                    0  97053000  2
#
#                          Nombre Cliente                        Producto  \
# 0                 DELOITTE ADVISORY SPA       SERV. MARKETING DE DATOS
# ...

# %%
withoutNA[' Total ']= withoutNA[' Total '].str.replace('-','-')
withoutNA[' Total ']= withoutNA[' Total '].str.replace(' ','')
withoutNA[' Total ']= withoutNA[' Total '].str.replace(',','')
withoutNA[' Total ']= withoutNA[' Total '].astype(float)
withoutNA
# Out:
#     Documento  Serie    Emisión          Vencimiento       RUT DV  \
# 0        7476   61.0 2022-01-31  2022-09-02 00:00:00  76863650  8
# 1        7477   61.0 2022-01-31  2022-01-21 00:00:00  77261280  K
# 2        7478   61.0 2022-01-31  2022-12-02 00:00:00  96806980  2
# 3        7479   61.0 2022-01-31  2022-12-02 00:00:00  96806980  2
# 4        7479   61.0 2022-01-31  2022-12-02 00:00:00  96806980  2
# ..        ...    ...        ...                  ...       ... ..
# 128      7596   61.0 2022-12-31                    0  99581960  0
# 129      7597   61.0 2022-12-31                    0  77140321  2
# 130      7598   61.0 2022-12-31                    0  96656410  5
# 131      7599   61.0 2022-12-31                    0  96655860  1
# 132      7600   61.0 2022-12-31                    0  97053000  2
#
#                          Nombre Cliente                        Producto  \
# 0                 DELOITTE ADVISORY SPA       SERV. MARKETING DE DATOS
# ...

# %%
droNA = dataframe.dropna()
droNA
# Out:
#      Documento  Serie     Emisión Vencimiento       RUT DV  \
# 0         7476     61   1/31/2022  09/02/2022  76863650  8
# 2         7478     61   1/31/2022  12/02/2022  96806980  2
# 3         7479     61   1/31/2022  12/02/2022  96806980  2
# 4         7479     61   1/31/2022  12/02/2022  96806980  2
# 5         7479     61   1/31/2022  12/02/2022  96806980  2
# 6         7480     61   1/31/2022  01/02/2022  96656410  5
# 7         7481     61   2/28/2022  19/03/2022  92580000  7
# 8         7482     61   2/28/2022  24/02/2022  86966100  7
# 9         7483     61   2/28/2022  26/03/2022  97023000  9
# 10        7484     61   2/28/2022  30/03/2022  97080000  K
# 11        7485     61   2/28/2022  30/03/2022  96806980  2
# 74        7545     61   7/28/2022  27/08/2022  60711000  K
# 75        7546     61   7/28/2022  25/09/2022  96799250  K
# 76        7547     61   7/31/2022  30/08/2022  77612410  9
# 78        7549     61   7/31/2022  30/08/2022  70017820  K
# ...

# %%
dataframe["Emisión"]= pd.to_datetime(dataframe["Emisión"])
dataframe
# Out:
#     Documento  Serie    Emisión Vencimiento       RUT DV  \
# 0        7476   61.0 2022-01-31  2022-09-02  76863650  8
# 1        7477   61.0 2022-01-31  2022-01-21  77261280  K
# 2        7478   61.0 2022-01-31  2022-12-02  96806980  2
# 3        7479   61.0 2022-01-31  2022-12-02  96806980  2
# 4        7479   61.0 2022-01-31  2022-12-02  96806980  2
# ..        ...    ...        ...         ...       ... ..
# 128      7596   61.0 2022-12-31         NaT  99581960  0
# 129      7597   61.0 2022-12-31         NaT  77140321  2
# 130      7598   61.0 2022-12-31         NaT  96656410  5
# 131      7599   61.0 2022-12-31         NaT  96655860  1
# 132      7600   61.0 2022-12-31         NaT  97053000  2
#
#                          Nombre Cliente                        Producto  \
# 0                 DELOITTE ADVISORY SPA       SERV. MARKETING DE DATOS
# 1                 FALABELLA RETAIL S.A.               BASES ANALITICAS
# ...

# %%
dataframe["Vencimiento"]= pd.to_datetime(dataframe["Vencimiento"])
dataframe
# Out:
#      Documento  Serie    Emisión Vencimiento       RUT DV  \
# 0         7476     61 2022-01-31  2022-09-02  76863650  8
# 1         7477     61 2022-01-31  2022-01-21  77261280  K
# 2         7478     61 2022-01-31  2022-12-02  96806980  2
# 3         7479     61 2022-01-31  2022-12-02  96806980  2
# 4         7479     61 2022-01-31  2022-12-02  96806980  2
# ..         ...    ...        ...         ...       ... ..
# 128       7596     61 2022-12-31         NaT  99581960  0
# 129       7597     61 2022-12-31         NaT  77140321  2
# 130       7598     61 2022-12-31         NaT  96656410  5
# 131       7599     61 2022-12-31         NaT  96655860  1
# 132       7600     61 2022-12-31         NaT  97053000  2
#
#                          Nombre Cliente                        Producto  \
# 0                 DELOITTE ADVISORY SPA       SERV. MARKETING DE DATOS
# 1                 FALABELLA RETAIL S.A.               BASES ANALITICAS
# ...

# %%
dataframe["Serie"] = dataframe["Serie"].astype(float)
dataframe
# Out:
#      Documento  Serie    Emisión Vencimiento       RUT DV  \
# 0         7476   61.0 2022-01-31  2022-09-02  76863650  8
# 1         7477   61.0 2022-01-31  2022-01-21  77261280  K
# 2         7478   61.0 2022-01-31  2022-12-02  96806980  2
# 3         7479   61.0 2022-01-31  2022-12-02  96806980  2
# 4         7479   61.0 2022-01-31  2022-12-02  96806980  2
# ..         ...    ...        ...         ...       ... ..
# 128       7596   61.0 2022-12-31         NaT  99581960  0
# 129       7597   61.0 2022-12-31         NaT  77140321  2
# 130       7598   61.0 2022-12-31         NaT  96656410  5
# 131       7599   61.0 2022-12-31         NaT  96655860  1
# 132       7600   61.0 2022-12-31         NaT  97053000  2
#
#                          Nombre Cliente                        Producto  \
# 0                 DELOITTE ADVISORY SPA       SERV. MARKETING DE DATOS
# 1                 FALABELLA RETAIL S.A.               BASES ANALITICAS
# ...

# %%
dataframe["Documento"]=dataframe["Documento"].astype(str)
dataframe
# Out:
#     Documento  Serie    Emisión Vencimiento       RUT DV  \
# 0        7476   61.0 2022-01-31  2022-09-02  76863650  8
# 1        7477   61.0 2022-01-31  2022-01-21  77261280  K
# 2        7478   61.0 2022-01-31  2022-12-02  96806980  2
# 3        7479   61.0 2022-01-31  2022-12-02  96806980  2
# 4        7479   61.0 2022-01-31  2022-12-02  96806980  2
# ..        ...    ...        ...         ...       ... ..
# 128      7596   61.0 2022-12-31         NaT  99581960  0
# 129      7597   61.0 2022-12-31         NaT  77140321  2
# 130      7598   61.0 2022-12-31         NaT  96656410  5
# 131      7599   61.0 2022-12-31         NaT  96655860  1
# 132      7600   61.0 2022-12-31         NaT  97053000  2
#
#                          Nombre Cliente                        Producto  \
# 0                 DELOITTE ADVISORY SPA       SERV. MARKETING DE DATOS
# 1                 FALABELLA RETAIL S.A.               BASES ANALITICAS
# ...

# %%
dataframe[' Total ']= dataframe[' Total '].str.replace('-','-')
dataframe[' Total ']= dataframe[' Total '].str.replace(' ','')
dataframe[' Total ']= dataframe[' Total '].str.replace(',','')
dataframe[' Total ']= dataframe[' Total '].astype(float)
dataframe
# Out:
#     Documento  Serie    Emisión Vencimiento       RUT DV  \
# 0        7476   61.0 2022-01-31  2022-09-02  76863650  8
# 1        7477   61.0 2022-01-31  2022-01-21  77261280  K
# 2        7478   61.0 2022-01-31  2022-12-02  96806980  2
# 3        7479   61.0 2022-01-31  2022-12-02  96806980  2
# 4        7479   61.0 2022-01-31  2022-12-02  96806980  2
# ..        ...    ...        ...         ...       ... ..
# 128      7596   61.0 2022-12-31         NaT  99581960  0
# 129      7597   61.0 2022-12-31         NaT  77140321  2
# 130      7598   61.0 2022-12-31         NaT  96656410  5
# 131      7599   61.0 2022-12-31         NaT  96655860  1
# 132      7600   61.0 2022-12-31         NaT  97053000  2
#
#                          Nombre Cliente                        Producto  \
# 0                 DELOITTE ADVISORY SPA       SERV. MARKETING DE DATOS
# 1                 FALABELLA RETAIL S.A.               BASES ANALITICAS
# ...

# %%
dataframe.describe()
# Out:
#        Serie           RUT        Total           ANULA          NUEVA
# count  133.0  1.330000e+02  7.600000e+01     133.000000     100.000000
# mean    61.0  8.583000e+07 -6.682720e+06  174785.000000  175075.340000
# std      0.0  1.094277e+07  1.562697e+07    1375.869384    1028.029037
# min     61.0  5.331057e+07 -1.179371e+08  171890.000000  173132.000000
# 25%     61.0  7.686365e+07 -5.470616e+06  173602.000000  174249.750000
# 50%     61.0  8.696610e+07 -1.643133e+06  174635.000000  175369.000000
# 75%     61.0  9.680698e+07 -5.265902e+05  175747.000000  176084.250000
# max     61.0  9.958196e+07 -2.807600e+04  177456.000000  176857.000000

# %%
# !pip install openpyxl
salida = dataframe.groupby(["Documento","Nombre Cliente"]).sum(" Total ")
salida2 = salida.to_excel("salida.xlsx")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 KB 43.0 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2213a1fb-2cb0-4a13-b303-78cece87c4ea' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
