# %%
import pandas as pd


df = pd.read_excel("C:/Users/joparra/Downloads/example.xls")

Quantity= int (df["PROVEEDOR"].count())

print ("Number of vendors:", Quantity)
Covering = int (Quantity * 0.20)

print ("Number of selected items:", Covering)
sample= df.sample(n=Covering)
print ("Sample selected:", sample)
sample.to_csv("C:/Users/joparra/Downloads/contractor_sample.xls")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [1], line 4
#       1 import pandas as pd
# ----> 4 df = pd.read_excel("C:/Users/joparra/Downloads/example.xls")
#       6 Quantity= int (df["PROVEEDOR"].count())
#       8 print ("Number of vendors:", Quantity)
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/util/_decorators.py:299, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     294     msg = (
#     295         f"Starting with Pandas version {version} all arguments of "
#     296         f"{func.__name__}{arguments} will be keyword-only"
#     297     )
#     298     warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2213a1fb-2cb0-4a13-b303-78cece87c4ea' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
